# %% [markdown]
# # this is line one.
# ### this is line two with three hash tags.
# - this is point one.
#     - this is sub point one of point one.
#     - this is sub point two of point one.
# - this is point two.

# %%
print("Hello world")
# Out:
# Hello world

# %%
#this is comment
print("Hello world")
# Out:
# Hello world
