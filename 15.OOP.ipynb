# %% [markdown]
# # OOP
# ```python
# # class definition
# class ClassNameHere(object):
#     def __init__(self, paremeters, *args, **kwargs):
#         """constructor"""
#         # defination
#         self.attribute1 = parameters
#
#     def method1(self):
#         #definition
#
#     def method2(self):
#         #definition
#
# #object creation
# obj_name = ClassNameHere(arguments_for_constructor)
#
# # attribute access using doe operator
# obj_name.attribute1
# obj_name.attribute2
#
# #method access using dot operator
# obj_name.method1(arguments_for_method1)
# obj_name.method2(arguments_for_method2)
#
# ```

# %%
class Person(object):
    def __init__(self, f_name, l_name, age):
        self.name = f_name + " " +l_name
        self.age = age

    def get_details(self):
        return f"Famous person is {self.name}"
    
    def __str__(self):
        msg = self.get_details()
        print(f"{msg = }")
        return f"Person (name: {self.name}, age:{self.age})"

person1 = Person('Ankit', 'Bista', 24)
# print(person1.name)
# print(person1.age)
# print(person1.get_details())
print(person1)
# Out:
# msg = 'Famous person is Ankit Bista'
# Person (name: Ankit Bista, age:24)

# %%
person2 = Person('Sashant', 'Dangol', 24)
print(person2)
# Out:
# msg = 'Famous person is Sashant Dangol'
# Person (name: Sashant Dangol, age:24)

# %%
print(person1)
# Out:
# <__main__.Person object at 0x000002416D8E71A0>

# %% [markdown]
# # Inheritance

# %%
class Employee(Person):
    def __init__(self, id, salary, f_name, l_name, age):
        self.id = id
        self.salary = salary
        super().__init__(f_name, l_name, age)
    def get_salary(self):
        return f"{self.salary = }"

emp_1 = Employee(100, 20000, "abc","xyz",23)
emp_1.get_salary()
# Out:
# 'self.salary = 20000'

# %%
emp_1.get_details()
# Out:
# 'Famous person is abc xyz'

# %%
class Person2(object):
    def __init__(self, f_name, l_name, age):
        self.name = f_name + " " +l_name
        self.age = age

    def get_details(self):
        return f"Famous person is {self.name}"
    
class Employee2:
    def __init__(self, id, salary):
        self.id = id
        self.salary = salary
    def get_salary(self):
        return f"{self.salary = }"
    
class Teacher(Person2, Employee2):
    def __init__(self, f_name, l_name, age, id, salary):
        Person2.__init__(self, f_name, l_name, age)
        Employee2.__init__(self, id, salary)

t =  Teacher('a', 'b', 23, 100, 20000)
