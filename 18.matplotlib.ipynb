# %%
! pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([2,3,4,7])
y = np.array([2,5,6,9])

# %%
plt.figure(figsize=(5,2)) # figsize=(width,height)
plt.scatter(x,y,label='A')
plt.scatter(x+1,y-1,label='B',color='black', marker='*')
plt.xlabel("X-Label")
plt.ylabel("Y-Label")
plt.title("Title of the plot")
plt.legend()
plt.grid(axis = 'both')
plt.show()

# %% [markdown]
# ### Line plot

# %%
plt.figure(figsize=(5,3)) # figsize=(width,height)
plt.plot(x, y, marker = "*", mec ='red', mfc = 'black', c='green')
# plt.plot(x, y,"*", mec ='red', mfc = 'black')

# %%
plt.figure(figsize=(5,3)) # figsize=(width,height)
plt.plot(x, y,"<-g") # scatter plot
plt.plot(x-1, y+1,"<--r")
plt.plot(x-2, y+2,">-.b")
plt.plot(x-2, y+0.5,">:y", ms=15)

# %%
font1= {'family': 'serif', 'color': 'blue', 'size': 10}
font2= {'family': 'serif', 'color': 'darkred', 'size': 20}

plt.figure(figsize=(5,3)) # figsize=(width,height)
plt.plot(x, y,"<-g", linewidth = 5) # scatter plot
plt.xlabel("X-Ref", fontdict=font1) 
plt.title("Title",  fontdict= font2)
# Out:
# Text(0.5, 1.0, 'Title')

# %% [markdown]
# ### Bar Graph

# %%
labels = ['cycle', 'car', 'bus']
price_in_k = [50, 300, 250]

plt.figure(figsize= (5, 3))
plt.bar(labels, price_in_k, color='red', width= 0.3)
# Out:
# <BarContainer object of 3 artists>

# %%
labels = ['cycle', 'car', 'bus']
price_in_k = [50, 300, 250]

plt.figure(figsize= (5, 3))
plt.barh(labels, price_in_k, color='red', height=0.5, align ='edge')
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### Pie chart

# %%
labels = ['cycle', 'car', 'bus']
price_in_k = [50, 400, 250]

explodes = [0.2, 0, 0]
colors = ['red', 'green', 'black']

plt.pie(price_in_k, labels = labels , explode= explodes, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x250db330650>,
# ...
#  [Text(1.2674062809510076, 0.2892772355473826, 'cycle'),
#   Text(-0.6858389529157668, 0.8600144944496021, 'car'),
#   Text(0.4772723060025268, -0.9910656617616366, 'bus')])

# %% [markdown]
# ### Subplot

# %%
nr = 2
nc = 3
plt.subplot(nr, nc, 1)
plt.scatter(x,y,label='A')
plt.scatter(x+1,y-1,label='B',color='black', marker='*')
plt.xlabel("X-Label")
plt.ylabel("Y-Label")
plt.title("Title of the plot")
plt.legend()
plt.grid(axis = 'both')

plt.subplot(nr, nc, 2)
plt.plot(x, y, marker = "*", mec ='red', mfc = 'black', c='green')

plt.subplot(nr, nc, 3)
plt.barh(labels, price_in_k, color='red', height=0.5, align ='edge')

plt.subplot(nr, nc, 4)
plt.pie(price_in_k, labels = labels , explode= explodes, colors=colors)

plt.suptitle("Main Title")
plt.tight_layout()
