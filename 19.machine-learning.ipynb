# %%
! pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.7 MB 6.7 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.7 MB 4.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.4/8.7 MB 4.2 MB/s eta 0:00:02
#    -------------- ------------------------- 3.1/8.7 MB 4.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.7/8.7 MB 4.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.5/8.7 MB 3.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/8.7 MB 3.6 MB/s eta 0:00:02
#    -------------------------- ------------- 5.8/8.7 MB 3.6 MB/s eta 0:00:01
#    ------------------------------ --------- 6.6/8.7 MB 3.5 MB/s eta 0:00:01
#    --------------------------------- ------ 7.3/8.7 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 8.1/8.7 MB 3.6 MB/s eta 0:00:01
# ...

# %% [markdown]
#  - y = mx + c
#  - m = weight(w)
#  - c = bias(b)
