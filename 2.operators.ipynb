# %% [markdown]
# # operators

# %%
# exponential operator: output is folating point number
2 ** 3
# Out:
# 8

# %%
# floor division: output is always integer
5//2
# Out:
# 2

# %% [markdown]
# ### Type casting

# %%
a=4
print(a)
# Out:
# 4

# %%
float(a)
# Out:
# 4.0

# %%
float(3)
# Out:
# 3.0

# %% [markdown]
# # Data types
# ### int, float, str, bool, list, tuple, set, dictionary
# - list, tuple
#     - mutable as it can be compressed or expanded

# %% [markdown]
# # Logical Operators
# - and
# - or
# - not

# %%
a= 5
x = a
x is a
# Out:
# True
