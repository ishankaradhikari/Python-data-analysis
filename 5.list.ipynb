# %% [markdown]
# # List

# %%
# empty list
l1=[]

type(l1)
# Out:
# list

# %%
l2=list()
type(l2)
# Out:
# list

# %%
print(l1)
# Out:
# []

# %%
#adding elements in the list
l1.append(1)
print(l1)
# Out:
# [1]

# %%
#append inserts element in the last of the listl1.
append('This is string')
l1.append(5.0)
l1.append(l2) #we can append list inside another list
print(l1)
# Out:
# [1, 'This is string', 5.0, [], 5.0, []]

# %%
#to insert elements in perticualr index
l1.insert(2, 'inserted string')
print(l1)
# Out:
# [1, 'This is string', 'inserted string', 5.0, [], 5.0, []]

# %%
# accessing element of index 3 from list l1
l1[3]
# Out:
# 5.0

# %%
#updating values
l1[3] = 'New value'
print(l1)
# Out:
# [1, 'This is string', 'inserted string', 'New value', [], 5.0, []]

# %%
# Removing elements from the list
l1.remove('This is string')
print(l1)
# Out:
# [1, 'inserted string', 'New value', [], 5.0, []]

# %%
#default last value is popped
l1.pop()
print(l1)
# Out:
# [1, 'inserted string', 'New value', [], 5.0]

# %%
l1.pop()
# Out:
# 5.0

# %%
l1.pop()
print(l1)
# Out:
# [1, 'inserted string', 'New value']

# %%
#popping an element from perticular index
returned_val = l1.pop(1)
returned_val , l1
# Out:
# ('inserted string', [1, 'New value'])

# %%
l3 = [1, 2, 3]
l4 = [4, 5, 6]
#concataning the elements of two list
l3+l4
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l4+l3
# Out:
# [4, 5, 6, 1, 2, 3]

# %%
print(f"{l3=}")
print(f"{l4=}")
# Out:
# l3=[1, 2, 3]
# l4=[4, 5, 6]

# %%
# extend method
l3 = [1, 2, 3]
l4 = [4, 5, 6]

l4.extend(l3)

# %%
print(f"{l3=}")
print(f"{l4=}")
# Out:
# l3=[1, 2, 3]
# l4=[4, 5, 6, 1, 2, 3]

# %%
print(None)
# Out:
# None

# %%
#it references same memory location so change on any one list wil effect both
l5 = l3

# %%
l3, l5
# Out:
# ([1, 2, 3], [1, 2, 3])

# %%
l5[0] = 1000

# %%
l3, l5
# Out:
# ([1000, 2, 3], [1000, 2, 3])

# %%
#we can use copy to copy the elements of one list to another list in different memory location
l5 = l3.copy()
l3, l5
# Out:
# ([1000, 2, 3], [1000, 2, 3])

# %%
l5[0] = 0.1

# %%
l3, l5
# Out:
# ([1000, 2, 3], [0.1, 2, 3])

# %%
l3.reverse()

# %%
print(l3)
# Out:
# [3, 2, 1000]

# %%
l3.sort()
print(l3)
# Out:
# [2, 3, 1000]

# %%
l3.sort(reverse= True)
print(l3)
# Out:
# [1000, 3, 2]

# %%
# sorted function is used when we want to sort the list maintaining the original order of the elements in the list.
sorted(l3)
# Out:
# [2, 3, 1000]

# %%
l3
# Out:
# [1000, 3, 2]

# %% [markdown]
# # Slicing

# %%
l = [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
l[-4]
# Out:
# 60

# %%
print(l)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
# List_name[start_index: end_index: step (how_many_indices)]
l[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
l[0: 9: 1]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
l[2: 9]
# Out:
# [30, 40, 50, 60, 70, 80, 90]

# %%
l[2: 7:]
# Out:
# [30, 40, 50, 60, 70]

# %%
l[::2]
# Out:
# [10, 30, 50, 70, 90]

# %%
l[::3]
# Out:
# [10, 40, 70]

# %%
nested_l =[[1, 2, 3],
          [4, 5, 6],
          [7, 8, 9]]
print(nested_l)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
nested_l[1][1]
# Out:
# 5

# %%
nested_l =[[1, 2, 3, 40, 50],
          [4, 5, 6,70, 80],
          [7, 8, 9, 11, 21],
          [17, 18, 19, 12, 22]]
print(nested_l)
# Out:
# [[1, 2, 3, 40, 50], [4, 5, 6, 70, 80], [7, 8, 9, 11, 21], [17, 18, 19, 12, 22]]

# %%
nested_l[1][3]
# Out:
# 70
