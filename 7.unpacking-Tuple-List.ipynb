# %% [markdown]
# #

# %%
a=1, b=2
# Out:
#   Cell In[1], line 1
#     a=1, b=2
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
a=1 ; b=2

# %%
a=1
b=2

# %%
# valueError is raised when number of variables in left side of assignment operator are less than the number of elements in right side of assignment operator
a,b= 1,2, 3
print(f'{a = }')
print(f'{b = }')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a,b= 1,2, 3
#       2 print(f'{a = }')
#       3 print(f'{b = }')
#
# ValueError: too many values to unpack (expected 2)

# %%
f, *remaining, l= 1, 2, 3, 4, 5, 6, 7 
print(f"{f = }")
print(f"{remaining = }")
print(f"{l = }")
# Out:
# f = 1
# remaining = [2, 3, 4, 5, 6]
# l = 7

# %%
f, s, * remaining =1, 2, 3, 4, 5, 6, 7 
print(f"{f = }")
print(f"{s = }")
print(f"{remaining = }")
# Out:
# f = 1
# s = 2
# remaining = [3, 4, 5, 6, 7]

# %%
f, s, * remaining =[1, 2, 3, 4, 5, 6, 7 ]
print(f"{f = }")
print(f"{s = }")
print(f"{remaining = }")
# Out:
# f = 1
# s = 2
# remaining = [3, 4, 5, 6, 7]
